# %% [markdown]
# HW_02_EDA<br>
# Nicholas DeRobertis<br>
# I Pledge my Honor That I have Abided by the Stevens Honor System<br>
# CWID: 20006069

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:/users/nickd/cs513/HW/HW_02_EDA/breast-cancer-wisconsin.csv")

# %% [markdown]
# Summarizes the columns

# %%
print("\n")
print("Breast Cancer Wisconsin Data Summarized")
print("\n")
print(df.describe())

# %% [markdown]
# Replaces any ? with NA and counts how many NA are in the data

# %%
df.replace('?', pd.NA, inplace=True)
print("\n")
print("Number of Appearances of ? in the Data")
print(df.isna().sum())

# %% [markdown]
# Convert F6 Column to numeric

# %%
df['F6'] = pd.to_numeric(df['F6'], errors = 'coerce')

# %% [markdown]
# Fills in missing values with the mean of the column

# %%
numeric_columns = df.select_dtypes(include='number').columns
df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].mean())
df = df.round(2)

# %% [markdown]
# Class Vs. F6 Table

# %%
table = pd.crosstab(df['Class'], df['F6'])
print("\n")
print("Frequency Table of Class Vs. F6")
print(table)

# %% [markdown]
# Scatter Plot F1 to F6

# %%
pd.plotting.scatter_matrix(df.iloc[:, 1:7], figsize=(10,10))
plt.suptitle("Scatter Plot of F1 to F6")
plt.show()

# %% [markdown]
# Histogram F7 to F9

# %%
df.iloc[:, 7:10].plot(kind='box')
plt.title("Histogram Box Plot of F7 to F9")
plt.show()

# %% [markdown]
# Reloads the data

# %%
df = pd.read_csv(r"C:/users/nickd/cs513/HW/HW_02_EDA/breast-cancer-wisconsin.csv")

# %% [markdown]
# Removes any rows without values

# %%
df.dropna(inplace=True)

# %%
print("\n")
print("Reloaded Data with Rows Wihtout Data Removed")
print(df)

# %% [markdown]
# Resources Used<br>
# Excel to Python https://datatofish.com/read_excel/<br>
# Python to Jupyter Notebook https://stackoverflow.com/questions/62510114/converting-from-py-to-ipynb <br>
# Chat-GPT
